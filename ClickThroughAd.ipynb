# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("ads.csv")

# %%
df.head()
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                     62.26  32.0     69481.85                172.83
# 1                     41.73  31.0     61840.26                207.17
# 2                     44.40  30.0     57877.15                172.83
# 3                     59.88  28.0     56180.93                207.17
# 4                     49.21  30.0     54324.73                201.58
#
#                          Ad Topic Line             City  Gender  \
# 0      Decentralized real-time circuit         Lisafort    Male
# 1       Optional full-range projection  West Angelabury    Male
# 2  Total 5thgeneration standardization        Reyesfurt  Female
# 3          Balanced empowering success      New Michael  Female
# 4  Total 5thgeneration standardization     West Richard  Female
#
#                         Country            Timestamp  Clicked on Ad
# 0  Svalbard & Jan Mayen Islands  2016-06-09 21:43:05              0
# ...

# %%
df.describe()
# Out:
#        Daily Time Spent on Site           Age   Area Income  \
# count              10000.000000  10000.000000  10000.000000
# mean                  61.660757     35.940100  53840.047721
# std                   15.704142      8.572973  13343.708718
# min                   32.600000     19.000000  13996.500000
# 25%                   48.860000     29.000000  44052.302500
# 50%                   59.590000     35.000000  56180.930000
# 75%                   76.580000     42.000000  61840.260000
# max                   90.970000     60.000000  79332.330000
#
#        Daily Internet Usage  Clicked on Ad
# count          10000.000000   10000.000000
# mean             177.759831       0.491700
# std               40.820951       0.499956
# min              105.220000       0.000000
# 25%              140.150000       0.000000
# 50%              178.920000       0.000000
# 75%              212.670000       1.000000
# max              269.960000       1.000000

# %%
df.isnull().sum()
# Out:
# Daily Time Spent on Site    0
# Age                         0
# Area Income                 0
# Daily Internet Usage        0
# Ad Topic Line               0
# City                        0
# Gender                      0
# Country                     0
# Timestamp                   0
# Clicked on Ad               0
# dtype: int64

# %%
sns.countplot(data=df, x="Clicked on Ad");

# %%
sns.countplot(data=df, x="Clicked on Ad", hue="Gender");

# %%
df.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Gender', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
sns.boxplot(x="Daily Time Spent on Site", data = df, hue="Gender");

# %%
sns.jointplot(x="Age", y="Daily Time Spent on Site", data=df, kind="hex");

# %%
sns.pairplot(df)

# %%
sns.boxplot(x="Gender", y="Daily Internet Usage", data=df);

# %%
sns.boxplot(x="Gender", y="Daily Internet Usage", data=df, hue="Clicked on Ad");

# %%
df.head()
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                     62.26  32.0     69481.85                172.83
# 1                     41.73  31.0     61840.26                207.17
# 2                     44.40  30.0     57877.15                172.83
# 3                     59.88  28.0     56180.93                207.17
# 4                     49.21  30.0     54324.73                201.58
#
#                          Ad Topic Line             City  Gender  \
# 0      Decentralized real-time circuit         Lisafort    Male
# 1       Optional full-range projection  West Angelabury    Male
# 2  Total 5thgeneration standardization        Reyesfurt  Female
# 3          Balanced empowering success      New Michael  Female
# 4  Total 5thgeneration standardization     West Richard  Female
#
#                         Country            Timestamp  Clicked on Ad
# 0  Svalbard & Jan Mayen Islands  2016-06-09 21:43:05              0
# ...

# %%
plt.scatter(x="Age", y="Daily Time Spent on Site", data=df)

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df.head()
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                     62.26  32.0     69481.85                172.83
# 1                     41.73  31.0     61840.26                207.17
# 2                     44.40  30.0     57877.15                172.83
# 3                     59.88  28.0     56180.93                207.17
# 4                     49.21  30.0     54324.73                201.58
#
#                          Ad Topic Line             City  Gender  \
# 0      Decentralized real-time circuit         Lisafort    Male
# 1       Optional full-range projection  West Angelabury    Male
# 2  Total 5thgeneration standardization        Reyesfurt  Female
# 3          Balanced empowering success      New Michael  Female
# 4  Total 5thgeneration standardization     West Richard  Female
#
#                         Country            Timestamp  Clicked on Ad
# 0  Svalbard & Jan Mayen Islands  2016-06-09 21:43:05              0
# ...

# %%
df["Gender"] = df["Gender"].map({"Male": 1, "Female": 0})

# %%
df.head()
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                     62.26  32.0     69481.85                172.83
# 1                     41.73  31.0     61840.26                207.17
# 2                     44.40  30.0     57877.15                172.83
# 3                     59.88  28.0     56180.93                207.17
# 4                     49.21  30.0     54324.73                201.58
#
#                          Ad Topic Line             City  Gender  \
# 0      Decentralized real-time circuit         Lisafort       1
# 1       Optional full-range projection  West Angelabury       1
# 2  Total 5thgeneration standardization        Reyesfurt       0
# 3          Balanced empowering success      New Michael       0
# 4  Total 5thgeneration standardization     West Richard       0
#
#                         Country            Timestamp  Clicked on Ad
# 0  Svalbard & Jan Mayen Islands  2016-06-09 21:43:05              0
# ...

# %%
df.drop(["Ad Topic Line", "City", "Country"], axis=1, inplace = True)

# %%
df.head()
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  Gender  \
# 0                     62.26  32.0     69481.85                172.83       1
# 1                     41.73  31.0     61840.26                207.17       1
# 2                     44.40  30.0     57877.15                172.83       0
# 3                     59.88  28.0     56180.93                207.17       0
# 4                     49.21  30.0     54324.73                201.58       0
#
#              Timestamp  Clicked on Ad
# 0  2016-06-09 21:43:05              0
# 1  2016-01-16 17:56:05              0
# 2  2016-06-29 10:50:45              0
# 3  2016-06-21 14:32:32              0
# 4  2016-07-21 10:54:35              1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  10000 non-null  float64
#  1   Age                       10000 non-null  float64
#  2   Area Income               10000 non-null  float64
#  3   Daily Internet Usage      10000 non-null  float64
#  4   Gender                    10000 non-null  int64
#  5   Timestamp                 10000 non-null  object
#  6   Clicked on Ad             10000 non-null  int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 547.0+ KB

# %%
df.drop(["Timestamp"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  Gender  \
# 0                     62.26  32.0     69481.85                172.83       1
# 1                     41.73  31.0     61840.26                207.17       1
# 2                     44.40  30.0     57877.15                172.83       0
# 3                     59.88  28.0     56180.93                207.17       0
# 4                     49.21  30.0     54324.73                201.58       0
#
#    Clicked on Ad
# 0              0
# 1              0
# 2              0
# 3              0
# 4              1

# %%
X = df.iloc[:, 0:5].values
y = df.iloc[:, -1]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 9995    1
# 9996    0
# 9997    0
# 9998    1
# 9999    1
# Name: Clicked on Ad, Length: 10000, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(predictions, y_test))
# Out:
# [[1300  451]
#  [ 399 1150]]

# %%
print(classification_report(predictions, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.75      1751
#            1       0.72      0.74      0.73      1549
#
#     accuracy                           0.74      3300
#    macro avg       0.74      0.74      0.74      3300
# weighted avg       0.74      0.74      0.74      3300

# %% [markdown]
# #### Using Random Forest

# %%
model2 = RandomForestClassifier()

# %%
model2.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predictions2 = model2.predict(X_test)

# %%
print(confusion_matrix(predictions2, y_test))
# Out:
# [[1328  380]
#  [ 371 1221]]

# %%
print(classification_report(predictions2, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78      1708
#            1       0.76      0.77      0.76      1592
#
#     accuracy                           0.77      3300
#    macro avg       0.77      0.77      0.77      3300
# weighted avg       0.77      0.77      0.77      3300
